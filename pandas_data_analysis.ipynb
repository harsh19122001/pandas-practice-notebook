# %%
pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\dell\anaconda3\lib\site-packages (2.2.3)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\dell\anaconda3\lib\site-packages (from pandas) (2.1.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\dell\anaconda3\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\dell\anaconda3\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\dell\anaconda3\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\dell\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
s = pd.Series([10,20,30,40,50])
s
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %%
s.dtype
# Out:
# dtype('int64')

# %%
s.values
# Out:
# array([10, 20, 30, 40, 50])

# %%
s.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
s.name = 'calories'

# %%
print(s.name)
# Out:
# calories

# %%
s
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# Name: calories, dtype: int64

# %% [markdown]
# # Indexing

# %%
s[0]
# Out:
# np.int64(10)

# %%
s[0:2] #start(included) : stop(excluded): step value (values to jump)
# Out:
# 0    10
# 1    20
# Name: calories, dtype: int64

# %%
s[2:4]
# Out:
# 2    30
# 3    40
# Name: calories, dtype: int64

# %% [markdown]
# # iloc -> location based indexing

# %%
s.iloc[3]
# Out:
# np.int64(40)

# %%
s.iloc[[1,3,4]]
# Out:
# 1    20
# 3    40
# 4    50
# Name: calories, dtype: int64

# %%
index = ['apple' , 'banana' , 'grapes' , 'orange' , 'strawberry']

# %%
index
# Out:
# ['apple', 'banana', 'grapes', 'orange', 'strawberry']

# %%
s.index = index

# %%
s
# Out:
# apple         10
# banana        20
# grapes        30
# orange        40
# strawberry    50
# Name: calories, dtype: int64

# %%
s['grapes']
# Out:
# np.int64(30)

# %%
s.iloc[3]
# Out:
# np.int64(40)

# %% [markdown]
# # loc -> label based indexing

# %%
s.loc[['grapes' , 'apple' , 'strawberry']]
# Out:
# grapes        30
# apple         10
# strawberry    50
# Name: calories, dtype: int64

# %% [markdown]
# # In label based indexing your start as well as stop value both are included in the output.

# %%
s['banana' : 'orange']
# Out:
# banana    20
# grapes    30
# orange    40
# Name: calories, dtype: int64

# %%
fruit_protein = {'Avocado' : 2.0 , 'Guava' : 2.6 , 'Blackberries' : 2.0 , 'Orange' : 0.9 , 'Banana' : 1.1 , 'Apples' : 0.3 , 'Kiwi' : 1.1 , 'Pomegranate' : 1.7 , 'Mango' : 0.8 , 'Cherries' : 1.0}

# %%
fruit_protein # grams of protein
# Out:
# {'Avocado': 2.0,
#  'Guava': 2.6,
#  'Blackberries': 2.0,
#  'Orange': 0.9,
#  'Banana': 1.1,
#  'Apples': 0.3,
#  'Kiwi': 1.1,
#  'Pomegranate': 1.7,
#  'Mango': 0.8,
#  'Cherries': 1.0}

# %%
type(fruit_protein)
# Out:
# dict

# %%
s2 = pd.Series(fruit_protein , name = 'protein')
s2
# Out:
# Avocado         2.0
# Guava           2.6
# Blackberries    2.0
# Orange          0.9
# Banana          1.1
# Apples          0.3
# Kiwi            1.1
# Pomegranate     1.7
# Mango           0.8
# Cherries        1.0
# Name: protein, dtype: float64

# %% [markdown]
# # Conditional Selection

# %%
s2 > 1.0
# Out:
# Avocado          True
# Guava            True
# Blackberries     True
# Orange          False
# Banana           True
# Apples          False
# Kiwi             True
# Pomegranate      True
# Mango           False
# Cherries        False
# Name: protein, dtype: bool

# %%
s2[s2  > 1.0]
# Out:
# Avocado         2.0
# Guava           2.6
# Blackberries    2.0
# Banana          1.1
# Kiwi            1.1
# Pomegranate     1.7
# Name: protein, dtype: float64

# %% [markdown]
# # Logical operator

# %%
[(s2 > 0.5) & (s2 < 2)]
# Out:
# [Avocado         False
#  Guava           False
#  Blackberries    False
#  Orange           True
#  Banana           True
#  Apples          False
#  Kiwi             True
#  Pomegranate      True
#  Mango            True
#  Cherries         True
#  Name: protein, dtype: bool]

# %%
s2[(s2 > 0.5) & (s2 < 2)]
# Out:
# Orange         0.9
# Banana         1.1
# Kiwi           1.1
# Pomegranate    1.7
# Mango          0.8
# Cherries       1.0
# Name: protein, dtype: float64

# %%
# not operation
s2[~(s2 > 1.0)]
# Out:
# Orange      0.9
# Apples      0.3
# Mango       0.8
# Cherries    1.0
# Name: protein, dtype: float64

# %%
# Modifying the series
s2['mango'] = 2.8

# %%
s2
# Out:
# Avocado         2.0
# Guava           2.6
# Blackberries    2.0
# Orange          0.9
# Banana          1.1
# Apples          0.3
# Kiwi            1.1
# Pomegranate     1.7
# Mango           0.8
# Cherries        1.0
# mango           2.8
# Name: protein, dtype: float64

# %%
import numpy as np

# %%
ser = pd.Series(['a' , np.nan , 1 , np.nan , 2]) #ans
ser.notnull().sum()
# Out:
# np.int64(3)

# %%
data  = {
    'Name' : ['Alice' , 'Bob' , 'Charlie' , 'Dravid' , 'Eve' , 'Alice'] , 
    'Age' : [25 , 30 , 35 , np.nan , 29 , 25 ], 
    'Department' : ['HR' , 'IT' , 'Finance' , 'IT' , 'HR' , 'HR'] , 
    'Salary' : [50000, 60000 , 70000 , 62000 , np.nan , 50000]
}

# %%
data
# Out:
# {'Name': ['Alice', 'Bob', 'Charlie', 'Dravid', 'Eve', 'Alice'],
#  'Age': [25, 30, 35, nan, 29, 25],
#  'Department': ['HR', 'IT', 'Finance', 'IT', 'HR', 'HR'],
#  'Salary': [50000, 60000, 70000, 62000, nan, 50000]}

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#       Name   Age Department   Salary
# 0    Alice  25.0         HR  50000.0
# 1      Bob  30.0         IT  60000.0
# 2  Charlie  35.0    Finance  70000.0
# 3   Dravid   NaN         IT  62000.0
# 4      Eve  29.0         HR      NaN
# 5    Alice  25.0         HR  50000.0

# %%
df.head(2)
# Out:
#     Name   Age Department   Salary
# 0  Alice  25.0         HR  50000.0
# 1    Bob  30.0         IT  60000.0

# %%
df.tail(3)
# Out:
#      Name   Age Department   Salary
# 3  Dravid   NaN         IT  62000.0
# 4     Eve  29.0         HR      NaN
# 5   Alice  25.0         HR  50000.0

# %% [markdown]
# # loc and iloc

# %%
df.iloc[0:2] #if i want to aceess first 2 data set by using of iloc
# Out:
#     Name   Age Department   Salary
# 0  Alice  25.0         HR  50000.0
# 1    Bob  30.0         IT  60000.0

# %%
df.loc[0:1] #if i want to access first 2 data set by using of loc
# Out:
#     Name   Age Department   Salary
# 0  Alice  25.0         HR  50000.0
# 1    Bob  30.0         IT  60000.0

# %%
df.iloc[1:3]
# Out:
#       Name   Age Department   Salary
# 1      Bob  30.0         IT  60000.0
# 2  Charlie  35.0    Finance  70000.0

# %%
df.columns
# Out:
# Index(['Name', 'Age', 'Department', 'Salary'], dtype='object')

# %%
df.loc[1 : 3 , ['Age' , 'Department']]
# Out:
#     Age Department
# 1  30.0         IT
# 2  35.0    Finance
# 3   NaN         IT

# %%
df.iloc[1 : 3 , : 2] #rows,columns
# Out:
#       Name   Age
# 1      Bob  30.0
# 2  Charlie  35.0

# %%
df['Age']
# Out:
# 0    25.0
# 1    30.0
# 2    35.0
# 3     NaN
# 4    29.0
# 5    25.0
# Name: Age, dtype: float64

# %%
df[['Age' , 'Department']]
# Out:
#     Age Department
# 0  25.0         HR
# 1  30.0         IT
# 2  35.0    Finance
# 3   NaN         IT
# 4  29.0         HR
# 5  25.0         HR

# %%
df.drop('Age' , axis = 1 ) # if i want to change on the data frame then use parameter inplace = True
# Out:
#       Name Department   Salary
# 0    Alice         HR  50000.0
# 1      Bob         IT  60000.0
# 2  Charlie    Finance  70000.0
# 3   Dravid         IT  62000.0
# 4      Eve         HR      NaN
# 5    Alice         HR  50000.0

# %%
df
# Out:
#       Name   Age Department   Salary
# 0    Alice  25.0         HR  50000.0
# 1      Bob  30.0         IT  60000.0
# 2  Charlie  35.0    Finance  70000.0
# 3   Dravid   NaN         IT  62000.0
# 4      Eve  29.0         HR      NaN
# 5    Alice  25.0         HR  50000.0

# %%
df.shape
# Out:
# (6, 4)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Name        6 non-null      object
#  1   Age         5 non-null      float64
#  2   Department  6 non-null      object
#  3   Salary      5 non-null      float64
# dtypes: float64(2), object(2)
# memory usage: 324.0+ bytes

# %%
df.describe()
# Out:
#              Age        Salary
# count   5.000000      5.000000
# mean   28.800000  58400.000000
# std     4.147288   8532.291603
# min    25.000000  50000.000000
# 25%    25.000000  50000.000000
# 50%    29.000000  60000.000000
# 75%    30.000000  62000.000000
# max    35.000000  70000.000000

# %% [markdown]
# # Broadcasting

# %%
df
# Out:
#       Name   Age Department   Salary
# 0    Alice  25.0         HR  50000.0
# 1      Bob  30.0         IT  60000.0
# 2  Charlie  35.0    Finance  70000.0
# 3   Dravid   NaN         IT  62000.0
# 4      Eve  29.0         HR      NaN
# 5    Alice  25.0         HR  50000.0

# %%
df['Salary'] = df['Salary'] + 5000

# %%
df
# Out:
#       Name   Age Department   Salary
# 0    Alice  25.0         HR  55000.0
# 1      Bob  30.0         IT  65000.0
# 2  Charlie  35.0    Finance  75000.0
# 3   Dravid   NaN         IT  67000.0
# 4      Eve  29.0         HR      NaN
# 5    Alice  25.0         HR  55000.0

# %% [markdown]
# # Rnaming Columns

# %%
df.rename(columns = {'Department' : 'Dept'} , inplace = True)

# %%
df
# Out:
#       Name   Age     Dept   Salary
# 0    Alice  25.0       HR  55000.0
# 1      Bob  30.0       IT  65000.0
# 2  Charlie  35.0  Finance  75000.0
# 3   Dravid   NaN       IT  67000.0
# 4      Eve  29.0       HR      NaN
# 5    Alice  25.0       HR  55000.0

# %%
df['Salary'].unique()
# Out:
# array([55000., 65000., 75000., 67000.,    nan])

# %%
df['Dept'].unique()
# Out:
# array(['HR', 'IT', 'Finance'], dtype=object)

# %%
df['Dept'].value_counts()
# Out:
# Dept
# HR         3
# IT         2
# Finance    1
# Name: count, dtype: int64

# %%
df['Promoted Salary'] = df['Salary'] * 10 #New columns creation

# %%
df
# Out:
#       Name   Age     Dept   Salary  Promoted Salary
# 0    Alice  25.0       HR  55000.0         550000.0
# 1      Bob  30.0       IT  65000.0         650000.0
# 2  Charlie  35.0  Finance  75000.0         750000.0
# 3   Dravid   NaN       IT  67000.0         670000.0
# 4      Eve  29.0       HR      NaN              NaN
# 5    Alice  25.0       HR  55000.0         550000.0

# %% [markdown]
# # Data Cleaning

# %%
df.isnull().sum()
# Out:
# Name               0
# Age                1
# Dept               0
# Salary             1
# Promoted Salary    1
# dtype: int64

# %%
df.dropna(how = 'any') #any row that had any null value
# Out:
#       Name   Age     Dept   Salary  Promoted Salary
# 0    Alice  25.0       HR  55000.0         550000.0
# 1      Bob  30.0       IT  65000.0         650000.0
# 2  Charlie  35.0  Finance  75000.0         750000.0
# 5    Alice  25.0       HR  55000.0         550000.0

# %%
df.dropna(how = 'all') #if all the values in any row are null then we drop
# Out:
#       Name   Age     Dept   Salary  Promoted Salary
# 0    Alice  25.0       HR  55000.0         550000.0
# 1      Bob  30.0       IT  65000.0         650000.0
# 2  Charlie  35.0  Finance  75000.0         750000.0
# 3   Dravid   NaN       IT  67000.0         670000.0
# 4      Eve  29.0       HR      NaN              NaN
# 5    Alice  25.0       HR  55000.0         550000.0

# %%
df
# Out:
#       Name   Age     Dept   Salary  Promoted Salary
# 0    Alice  25.0       HR  55000.0         550000.0
# 1      Bob  30.0       IT  65000.0         650000.0
# 2  Charlie  35.0  Finance  75000.0         750000.0
# 3   Dravid   NaN       IT  67000.0         670000.0
# 4      Eve  29.0       HR      NaN              NaN
# 5    Alice  25.0       HR  55000.0         550000.0

# %%
df.fillna(0)
# Out:
#       Name   Age     Dept   Salary  Promoted Salary
# 0    Alice  25.0       HR  55000.0         550000.0
# 1      Bob  30.0       IT  65000.0         650000.0
# 2  Charlie  35.0  Finance  75000.0         750000.0
# 3   Dravid   0.0       IT  67000.0         670000.0
# 4      Eve  29.0       HR      0.0              0.0
# 5    Alice  25.0       HR  55000.0         550000.0

# %%
df['Age'].fillna(df['Age'].mean() )
# Out:
# 0    25.0
# 1    30.0
# 2    35.0
# 3    28.8
# 4    29.0
# 5    25.0
# Name: Age, dtype: float64

# %%
df['Salary'].fillna(df['Salary'].median())
# Out:
# 0    55000.0
# 1    65000.0
# 2    75000.0
# 3    67000.0
# 4    65000.0
# 5    55000.0
# Name: Salary, dtype: float64

# %%
df['Promoted Salary'].fillna(df['Promoted Salary'].median())
# Out:
# 0    550000.0
# 1    650000.0
# 2    750000.0
# 3    670000.0
# 4    650000.0
# 5    550000.0
# Name: Promoted Salary, dtype: float64

# %%
df
# Out:
#       Name   Age     Dept   Salary  Promoted Salary
# 0    Alice  25.0       HR  55000.0         550000.0
# 1      Bob  30.0       IT  65000.0         650000.0
# 2  Charlie  35.0  Finance  75000.0         750000.0
# 3   Dravid   NaN       IT  67000.0         670000.0
# 4      Eve  29.0       HR      NaN              NaN
# 5    Alice  25.0       HR  55000.0         550000.0

# %%
df['Age'].fillna(method = 'ffill')
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_9708\2409552794.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df['Age'].fillna(method = 'ffill')
# 0    25.0
# 1    30.0
# 2    35.0
# 3    35.0
# 4    29.0
# 5    25.0
# Name: Age, dtype: float64

# %%
df['Age'].fillna(method = 'bfill')
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_9708\2884979620.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df['Age'].fillna(method = 'bfill')
# 0    25.0
# 1    30.0
# 2    35.0
# 3    29.0
# 4    29.0
# 5    25.0
# Name: Age, dtype: float64

# %%
df
# Out:
#       Name   Age     Dept   Salary  Promoted Salary
# 0    Alice  25.0       HR  55000.0         550000.0
# 1      Bob  30.0       IT  65000.0         650000.0
# 2  Charlie  35.0  Finance  75000.0         750000.0
# 3   Dravid   NaN       IT  67000.0         670000.0
# 4      Eve  29.0       HR      NaN              NaN
# 5    Alice  25.0       HR  55000.0         550000.0

# %%
df['Name'] = df['Name'].replace('Charlie' , 'Rose' ) # for permenent change the data

# %%
df
# Out:
#      Name   Age     Dept   Salary  Promoted Salary
# 0   Alice  25.0       HR  55000.0         550000.0
# 1     Bob  30.0       IT  65000.0         650000.0
# 2    Rose  35.0  Finance  75000.0         750000.0
# 3  Dravid   NaN       IT  67000.0         670000.0
# 4     Eve  29.0       HR      NaN              NaN
# 5   Alice  25.0       HR  55000.0         550000.0

# %% [markdown]
# # Duplicates :

# %%
df_dup = df[df.duplicated()]
df_dup
# Out:
#     Name   Age Dept   Salary  Promoted Salary
# 5  Alice  25.0   HR  55000.0         550000.0

# %%
df
# Out:
#      Name   Age     Dept   Salary  Promoted Salary
# 0   Alice  25.0       HR  55000.0         550000.0
# 1     Bob  30.0       IT  65000.0         650000.0
# 2    Rose  35.0  Finance  75000.0         750000.0
# 3  Dravid   NaN       IT  67000.0         670000.0
# 4     Eve  29.0       HR      NaN              NaN
# 5   Alice  25.0       HR  55000.0         550000.0

# %%
df = df.drop_duplicates()

# %%
df
# Out:
#      Name   Age     Dept   Salary  Promoted Salary
# 0   Alice  25.0       HR  55000.0         550000.0
# 1     Bob  30.0       IT  65000.0         650000.0
# 2    Rose  35.0  Finance  75000.0         750000.0
# 3  Dravid   NaN       IT  67000.0         670000.0
# 4     Eve  29.0       HR      NaN              NaN

# %% [markdown]
# # Invail values :
# # Lamda -> python

# %%
df['Promoted Salary'] = df['Promoted Salary'].apply(lambda x : x/10 if x > 650000 else x)
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_9708\872529495.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Promoted Salary'] = df['Promoted Salary'].apply(lambda x : x/10 if x > 650000 else x)

# %%
df
# Out:
#      Name   Age     Dept   Salary  Promoted Salary
# 0   Alice  25.0       HR  55000.0         550000.0
# 1     Bob  30.0       IT  65000.0         650000.0
# 2    Rose  35.0  Finance  75000.0          75000.0
# 3  Dravid   NaN       IT  67000.0          67000.0
# 4     Eve  29.0       HR      NaN              NaN

# %% [markdown]
# # apply and lambda

# %%
name = 'alice_fernandes'
df[['first_name' , 'last_name']] = df['name'].str.split('_')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'name'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[85], line 2
#       1 name = 'alice_fernandes'
# ----> 2 df[['first_name' , 'last_name']] = df['name'].str.split('_')
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'name'

# %%
df

# %%
def multiplying_age(x):
    return x * 2
df['Age'] = df['Age'].apply(multiplying_age)
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_9708\1212106217.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Age'] = df['Age'].apply(multiplying_age)

# %%
df
# Out:
#      Name   Age     Dept   Salary  Promoted Salary
# 0   Alice  50.0       HR  55000.0         550000.0
# 1     Bob  60.0       IT  65000.0         650000.0
# 2    Rose  70.0  Finance  75000.0          75000.0
# 3  Dravid   NaN       IT  67000.0          67000.0
# 4     Eve  58.0       HR      NaN              NaN

# %%
df['Age'] = df['Age'].apply(lambda x: x/2)
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_9708\252814256.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Age'] = df['Age'].apply(lambda x: x/2)

# %%
df
# Out:
#      Name   Age     Dept   Salary  Promoted Salary
# 0   Alice  25.0       HR  55000.0         550000.0
# 1     Bob  30.0       IT  65000.0         650000.0
# 2    Rose  35.0  Finance  75000.0          75000.0
# 3  Dravid   NaN       IT  67000.0          67000.0
# 4     Eve  29.0       HR      NaN              NaN

# %%
df['Age'] = df['Age'].apply(lambda x: x*2)
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_9708\1864911622.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Age'] = df['Age'].apply(lambda x: x*2)

# %%
df
# Out:
#      Name   Age     Dept   Salary  Promoted Salary
# 0   Alice  50.0       HR  55000.0         550000.0
# 1     Bob  60.0       IT  65000.0         650000.0
# 2    Rose  70.0  Finance  75000.0          75000.0
# 3  Dravid   NaN       IT  67000.0          67000.0
# 4     Eve  58.0       HR      NaN              NaN

# %% [markdown]
# # Joins & Merges

# %%
department_info = {
    'Dept' : ['HR' , 'IT' , 'Finance'],
    'Location' : ['New York' , 'San Francisco' , 'Chicago'],
    'Manager' : ['Laura' , 'Steve' , 'Nina']
}
df2 = pd.DataFrame(department_info)

# %%
df2
# Out:
#       Dept       Location Manager
# 0       HR       New York   Laura
# 1       IT  San Francisco   Steve
# 2  Finance        Chicago    Nina

# %%
df2.columns
# Out:
# Index(['Dept', 'Location', 'Manager'], dtype='object')

# %%
pd.concat([df , df2])
# Out:
#      Name   Age     Dept   Salary  Promoted Salary       Location Manager
# 0   Alice  50.0       HR  55000.0         550000.0            NaN     NaN
# 1     Bob  60.0       IT  65000.0         650000.0            NaN     NaN
# 2    Rose  70.0  Finance  75000.0          75000.0            NaN     NaN
# 3  Dravid   NaN       IT  67000.0          67000.0            NaN     NaN
# 4     Eve  58.0       HR      NaN              NaN            NaN     NaN
# 0     NaN   NaN       HR      NaN              NaN       New York   Laura
# 1     NaN   NaN       IT      NaN              NaN  San Francisco   Steve
# 2     NaN   NaN  Finance      NaN              NaN        Chicago    Nina

# %%
pd.concat([df , df2] , axis = 1)
# Out:
#      Name   Age     Dept   Salary  Promoted Salary     Dept       Location  \
# 0   Alice  50.0       HR  55000.0         550000.0       HR       New York
# 1     Bob  60.0       IT  65000.0         650000.0       IT  San Francisco
# 2    Rose  70.0  Finance  75000.0          75000.0  Finance        Chicago
# 3  Dravid   NaN       IT  67000.0          67000.0      NaN            NaN
# 4     Eve  58.0       HR      NaN              NaN      NaN            NaN
#
#   Manager
# 0   Laura
# 1   Steve
# 2    Nina
# 3     NaN
# 4     NaN

# %%
pd.merge(df,df2 , on = 'Dept' )
# Out:
#      Name   Age     Dept   Salary  Promoted Salary       Location Manager
# 0   Alice  50.0       HR  55000.0         550000.0       New York   Laura
# 1     Bob  60.0       IT  65000.0         650000.0  San Francisco   Steve
# 2    Rose  70.0  Finance  75000.0          75000.0        Chicago    Nina
# 3  Dravid   NaN       IT  67000.0          67000.0  San Francisco   Steve
# 4     Eve  58.0       HR      NaN              NaN       New York   Laura

# %%
data = pd.read_excel(r'C:\Users\Dell\Downloads\house_price_dataset.xlsx')

# %%
data
# Out:
#     House_ID  Bedrooms  Bathrooms  Area_sqft   Location  Year_Built  \
# 0          1         2          1        900      Delhi        2010
# 1          2         3          2       1200     Mumbai        2015
# 2          3         4          3       1800      Delhi        2012
# 3          4         3          2       1400       Pune        2018
# 4          5         2          1        950       Pune        2005
# 5          6         1          1        700      Delhi        2000
# 6          7         5          4       2400  Bangalore        2020
# 7          8         4          3       2000     Mumbai        2017
# 8          9         3          2       1500       Pune        2013
# 9         10         2          1       1000      Delhi        2008
# 10        11         3          2       1300     Mumbai        2016
# 11        12         4          3       1750       Pune        2014
# 12        13         5          4       2600  Bangalore        2021
# 13        14         3          2       1450      Delhi        2011
# 14        15         2          1        900       Pune        2006
# 15        16         1          1        650      Delhi        1998
# 16        17         4          3       1900  Bangalore        2019
# 17        18         3          2       1250     Mumbai        2015
# 18        19         2          1        850      Delhi        2007
# 19        20         3          2       1350       Pune        2013
#
#         Furnishing  Parking  Floor  Total_Floors  Price_Lakhs
# 0   Semi-Furnished        1      2             5           65
# 1        Furnished        1      5            10          120
# 2      Unfurnished        2      3             6          150
# 3        Furnished        1      7            12           90
# 4   Semi-Furnished        0      1             4           50
# 5      Unfurnished        0      0             3           30
# 6        Furnished        2     10            15          220
# 7   Semi-Furnished        2      6            12          160
# 8      Unfurnished        1      4             8           95
# 9   Semi-Furnished        0      2             5           55
# 10       Furnished        1      5            10          140
# 11     Unfurnished        2      3             7          130
# 12       Furnished        2      8            15          250
# 13  Semi-Furnished        1      4             9           85
# 14     Unfurnished        0      1             4           48
# 15     Unfurnished        0      0             3           28
# 16       Furnished        2      7            12          200
# 17  Semi-Furnished        1      5             8          145
# 18     Unfurnished        0      2             5           52
# 19       Furnished        1      3             6          100

# %%
data.head()
# Out:
#    House_ID  Bedrooms  Bathrooms  Area_sqft Location  Year_Built  \
# 0         1         2          1        900    Delhi        2010
# 1         2         3          2       1200   Mumbai        2015
# 2         3         4          3       1800    Delhi        2012
# 3         4         3          2       1400     Pune        2018
# 4         5         2          1        950     Pune        2005
#
#        Furnishing  Parking  Floor  Total_Floors  Price_Lakhs
# 0  Semi-Furnished        1      2             5           65
# 1       Furnished        1      5            10          120
# 2     Unfurnished        2      3             6          150
# 3       Furnished        1      7            12           90
# 4  Semi-Furnished        0      1             4           50

# %%
data.shape
# Out:
# (20, 11)

# %%
data.size
# Out:
# 220

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   House_ID      20 non-null     int64
#  1   Bedrooms      20 non-null     int64
#  2   Bathrooms     20 non-null     int64
#  3   Area_sqft     20 non-null     int64
#  4   Location      20 non-null     object
#  5   Year_Built    20 non-null     int64
#  6   Furnishing    20 non-null     object
#  7   Parking       20 non-null     int64
#  8   Floor         20 non-null     int64
#  9   Total_Floors  20 non-null     int64
#  10  Price_Lakhs   20 non-null     int64
# dtypes: int64(9), object(2)
# memory usage: 1.8+ KB

# %%
data = {"names" : ["Amit" , "Rohit" , "Sara" , "Neha"] ,
      "age" : [21 , 25 , 19 , 22] ,
        "marks" : [85 , 90 , 88 ,70]
       }

# %%
data
# Out:
# {'names': ['Amit', 'Rohit', 'Sara', 'Neha'],
#  'age': [21, 25, 19, 22],
#  'marks': [85, 90, 88, 70]}

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#    names  age  marks
# 0   Amit   21     85
# 1  Rohit   25     90
# 2   Sara   19     88
# 3   Neha   22     70

# %%
df.rename(columns = {"marks" : "obtained marks"} , inplace = True)

# %%
df
# Out:
#    names  age  obtained marks
# 0   Amit   21              85
# 1  Rohit   25              90
# 2   Sara   19              88
# 3   Neha   22              70

# %%
df.sort_values(by = "obtained marks" , ascending = True)
# Out:
#    names  age  obtained marks
# 3   Neha   22              70
# 0   Amit   21              85
# 2   Sara   19              88
# 1  Rohit   25              90

# %%
df
# Out:
#    names  age  obtained marks
# 0   Amit   21              85
# 1  Rohit   25              90
# 2   Sara   19              88
# 3   Neha   22              70

# %%
df.reset_index(drop = True , inplace = True)

# %%
df
# Out:
#    names  age  obtained marks
# 0   Amit   21              85
# 1  Rohit   25              90
# 2   Sara   19              88
# 3   Neha   22              70

# %%
df[["names" , "obtained marks"]]
# Out:
#    names  obtained marks
# 0   Amit              85
# 1  Rohit              90
# 2   Sara              88
# 3   Neha              70

# %%
data = pd.read_excel(r'C:\Users\Dell\Downloads\people_data_with_missing.xlsx')

# %%
data
# Out:
#                Name   Age       City
# 0       Amit Sharma  21.0   Jabalpur
# 1       Rohit Verma   NaN     Bhopal
# 2        Neha Gupta  22.0        NaN
# 3     Saurabh Singh  24.0      Delhi
# 4               NaN  20.0     Mumbai
# 5       Kunal Yadav  23.0       Pune
# 6       Ayesha Khan   NaN    Lucknow
# 7      Manish Patel  27.0        NaN
# 8          Riya Sen  18.0    Kolkata
# 9        Arjun Nair  26.0      Kochi
# 10      Simran Kaur  21.0        NaN
# 11   Harshit Tiwari   NaN     Nagpur
# 12       Mehul Soni  23.0      Surat
# 13       Ananya Roy   NaN        NaN
# 14      Vikas Dubey  29.0    Gwalior
# 15  Shreya Malhotra  24.0      Noida
# 16       Dev Mishra  20.0        NaN
# 17              NaN  21.0    Udaipur
# 18      Abhinav Rao  26.0  Hyderabad
# 19     Kritika Bose   NaN     Ranchi

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#                Name   Age       City
# 0       Amit Sharma  21.0   Jabalpur
# 1       Rohit Verma   NaN     Bhopal
# 2        Neha Gupta  22.0        NaN
# 3     Saurabh Singh  24.0      Delhi
# 4               NaN  20.0     Mumbai
# 5       Kunal Yadav  23.0       Pune
# 6       Ayesha Khan   NaN    Lucknow
# 7      Manish Patel  27.0        NaN
# 8          Riya Sen  18.0    Kolkata
# 9        Arjun Nair  26.0      Kochi
# 10      Simran Kaur  21.0        NaN
# 11   Harshit Tiwari   NaN     Nagpur
# 12       Mehul Soni  23.0      Surat
# 13       Ananya Roy   NaN        NaN
# 14      Vikas Dubey  29.0    Gwalior
# 15  Shreya Malhotra  24.0      Noida
# 16       Dev Mishra  20.0        NaN
# 17              NaN  21.0    Udaipur
# 18      Abhinav Rao  26.0  Hyderabad
# 19     Kritika Bose   NaN     Ranchi

# %%
df.head(10)
# Out:
#             Name   Age      City
# 0    Amit Sharma  21.0  Jabalpur
# 1    Rohit Verma   NaN    Bhopal
# 2     Neha Gupta  22.0       NaN
# 3  Saurabh Singh  24.0     Delhi
# 4            NaN  20.0    Mumbai
# 5    Kunal Yadav  23.0      Pune
# 6    Ayesha Khan   NaN   Lucknow
# 7   Manish Patel  27.0       NaN
# 8       Riya Sen  18.0   Kolkata
# 9     Arjun Nair  26.0     Kochi

# %%
df['Age']
# Out:
# 0     21.0
# 1      NaN
# 2     22.0
# 3     24.0
# 4     20.0
# 5     23.0
# 6      NaN
# 7     27.0
# 8     18.0
# 9     26.0
# 10    21.0
# 11     NaN
# 12    23.0
# 13     NaN
# 14    29.0
# 15    24.0
# 16    20.0
# 17    21.0
# 18    26.0
# 19     NaN
# Name: Age, dtype: float64

# %%
df.describe()
# Out:
#              Age
# count  15.000000
# mean   23.000000
# std     3.023716
# min    18.000000
# 25%    21.000000
# 50%    23.000000
# 75%    25.000000
# max    29.000000

# %%
df['Age'].fillna(df['Age'].mean())
# Out:
# 0     21.0
# 1     23.0
# 2     22.0
# 3     24.0
# 4     20.0
# 5     23.0
# 6     23.0
# 7     27.0
# 8     18.0
# 9     26.0
# 10    21.0
# 11    23.0
# 12    23.0
# 13    23.0
# 14    29.0
# 15    24.0
# 16    20.0
# 17    21.0
# 18    26.0
# 19    23.0
# Name: Age, dtype: float64

# %%
df['Age'].fillna(0)
# Out:
# 0     21.0
# 1      0.0
# 2     22.0
# 3     24.0
# 4     20.0
# 5     23.0
# 6      0.0
# 7     27.0
# 8     18.0
# 9     26.0
# 10    21.0
# 11     0.0
# 12    23.0
# 13     0.0
# 14    29.0
# 15    24.0
# 16    20.0
# 17    21.0
# 18    26.0
# 19     0.0
# Name: Age, dtype: float64

# %%
df.isnull().sum()
# Out:
# Name    2
# Age     5
# City    5
# dtype: int64

# %%
df.isnull()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[65], line 1
# ----> 1 df.isnull(True)
#
# TypeError: DataFrame.isnull() takes 1 positional argument but 2 were given

# %%
df1 = pd.DataFrame({
    "Name": ["Amit", "Rohit", "Neha", "Simran", "Kunal", "Ayesha"],
    "Salary": [25000, 45000, 37000, 52000, 30000, 28000]
})

# %%
df1
# Out:
#      Name  Salary
# 0    Amit   25000
# 1   Rohit   45000
# 2    Neha   37000
# 3  Simran   52000
# 4   Kunal   30000
# 5  Ayesha   28000

# %%
df1[df1['Salary']>30000]
# Out:
#      Name  Salary
# 1   Rohit   45000
# 2    Neha   37000
# 3  Simran   52000

# %%
df1[(df1['Salary']>=25000) & (df1['Salary']<=40000)]
# Out:
#      Name  Salary
# 0    Amit   25000
# 2    Neha   37000
# 4   Kunal   30000
# 5  Ayesha   28000

# %%
df1.nlargest(3 , 'Salary')
# Out:
#      Name  Salary
# 3  Simran   52000
# 1   Rohit   45000
# 2    Neha   37000

# %%
df1.nsmallest(3 , 'Salary')
# Out:
#      Name  Salary
# 0    Amit   25000
# 5  Ayesha   28000
# 4   Kunal   30000

# %%
df1
# Out:
#      Name  Salary
# 0    Amit   25000
# 1   Rohit   45000
# 2    Neha   37000
# 3  Simran   52000
# 4   Kunal   30000
# 5  Ayesha   28000

# %%
df2 = pd.DataFrame({'Salary' :(25000 , 45000 , 28000 , 47000 , 35000 , 60000) , 
                   'Name' : ('Virat' , 'MS Dhoni' , 'Rohit' , 'Hardik Pandya' , 'Shreyas iyer' , 'Sir Jadeja') , 
                    'Department' : ('HR' , 'IT' , 'Finance' , 'IT' , 'HR' , 'Finance') 
                   })

# %%
df2
# Out:
#    Salary           Name Department
# 0   25000          Virat         HR
# 1   45000       MS Dhoni         IT
# 2   28000          Rohit    Finance
# 3   47000  Hardik Pandya         IT
# 4   35000   Shreyas iyer         HR
# 5   60000     Sir Jadeja    Finance

# %%
df2.groupby('Department')['Salary'].mean()
# Out:
# Department
# Finance    44000.0
# HR         30000.0
# IT         46000.0
# Name: Salary, dtype: float64

# %%
df2.groupby('Department')['Salary'].max()
# Out:
# Department
# Finance    60000
# HR         35000
# IT         47000
# Name: Salary, dtype: int64

# %%
df2.groupby('Department')['Salary'].count()
# Out:
# Department
# Finance    2
# HR         2
# IT         2
# Name: Salary, dtype: int64

# %%
df2.groupby('Department')['Salary'].sum()
# Out:
# Department
# Finance    88000
# HR         60000
# IT         92000
# Name: Salary, dtype: int64

# %%
df2.groupby('Department').agg({
    'Salary' : ['mean' , 'max' , 'min' , 'count' , 'sum']
})
# Out:
#              Salary
#                mean    max    min count    sum
# Department
# Finance     44000.0  60000  28000     2  88000
# HR          30000.0  35000  25000     2  60000
# IT          46000.0  47000  45000     2  92000

# %%
df2['Salary'].sort_values()
# Out:
# 0    25000
# 2    28000
# 4    35000
# 1    45000
# 3    47000
# 5    60000
# Name: Salary, dtype: int64

# %%
df2['Salary'].sort_values(ascending = False)
# Out:
# 5    60000
# 3    47000
# 1    45000
# 4    35000
# 2    28000
# 0    25000
# Name: Salary, dtype: int64
